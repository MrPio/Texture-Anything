# %%
import sys
import trimesh

sys.path.append("..")
from src import *

# %% [markdown]
# # Visualize a 3D object from the dataset (Objaverse)
# ##### ℹ️ This notebook requires some Objaverse samples to be downloaded in the `dataset/objaverse/objects` folder.
# This notebook visualize random Objaverse samples.

# %%
dataset = ObjaverseDataset3D()

# %% [markdown]
# Note: all the downloaded files are `.glb`.

# %%
UID = "2dd06635592e4a40bd09b9921cb73754"
obj = dataset[UID]
imshow([obj.rendering, obj.textures[0], obj.draw_uv()], cols=3)
trimesh.load(obj.path).show()
# Out:
# [Errno 2] No such file or directory: '/home/vmorelli-iit.local/Projects/Texture-Anything/dataset/objaverse/objaverse_glbs.parquet'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 UID = "2dd06635592e4a40bd09b9921cb73754"
#       2 obj = dataset[UID]
# ----> 3 imshow([obj.rendering, obj.textures[0], obj.draw_uv()], cols=3)
#       4 trimesh.load(obj.path).show()
#
# AttributeError: 'NoneType' object has no attribute 'rendering'
