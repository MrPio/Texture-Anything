# %%
import sys
import os
from huggingface_hub import login

# %% [markdown]
# # Download ShapeNetCore dataset
# This notebook download the entire ShapeNetCore dataset from Huggingface. Since it's a restricted dataset, you need to request access and then generate a token from your account settings.

# %%
os.environ['HF_TOKEN']='YOUT_TOKEN'

# %%
login(os.environ['HF_TOKEN'])
# !sh download_shapenet.sh ../.shapenet
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# --2025-05-09 09:50:04--  https://huggingface.co/datasets/ShapeNet/ShapeNetCore/resolve/main/02691156.zip
# Resolving huggingface.co (huggingface.co)... 108.138.192.59, 108.138.192.12, 108.138.192.82, ...
# Connecting to huggingface.co (huggingface.co)|108.138.192.59|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
#  Use `unzip \*.zip` to unpack
