# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import sys
import trimesh

sys.path.append(str(Path("..").resolve()))
from src import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = ShapeNetCoreDataset3D()
dataset2 = ObjaverseDataset3D()

# %%
UID = "9319229e8b90b7d794a57adad86ebb52"
obj = dataset[UID]
renderings = obj.render(samples=1, views=3)
# Out:
# OBJ import of 'model_normalized.obj' took 86.90 ms
# /leonardo_scratch/fast/IscrC_MACRO/Objaverse/dataset/shapenetcore/objects/04090263/9319229e8b90b7d794a57adad86ebb52/models/model_normalized.obj
#   0%|          | 0/3 [00:00<?, ?it/s]
# Fra:1 Mem:14.29M (Peak 14.29M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | model_normalized
# Fra:1 Mem:15.05M (Peak 15.31M) | Time:00:00.10 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:14.57M (Peak 15.31M) | Time:00:00.10 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:14.57M (Peak 15.31M) | Time:00:00.10 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:14.57M (Peak 15.31M) | Time:00:00.10 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:14.57M (Peak 15.31M) | Time:00:00.10 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# ...

# %%
plot_images(renderings, cols=3,size=5)
