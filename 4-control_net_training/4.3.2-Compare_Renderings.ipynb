# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
import pandas as pd

sys.path.append("..")
from src import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = ObjaverseDataset3D()
views = 3

# %%
TESTSET_DIR = Path("dataset/test")
REND_DIR = Path("renderings")
dirs = [
    "gt",
    "sd15_mlsd",
    "sd15_ours",
    # "sdxl_ours",
    "sdxl_mlsd_llite",
    "sdxl_ours_llite",
]
testset = pd.read_json(TESTSET_DIR / "metadata.jsonl", orient="records", lines=True)
testset.index = pd.Series(testset.uv_file_name.map(lambda x: Path(x).stem), name="uid")

# %% [markdown]
# Use `generate_renderings.py` to generate the renderings.

# %%
for uid in (pbar := tqdm(testset.index)):
    pbar.set_description_str(testset.caption[uid][:50])
    imshow(
        images={
            f"{dir} {view}": REND_DIR / dir / f"{uid.split('_')[0]}_{view}.png"
            for view in range(views)
            for dir in dirs
        },
        size=6,
        cols=len(dirs),
        path=mkdir("output/renderings") / f"{uid}.png",
    )
# Out:
# a vibrant red box with a smooth surface and a sing:   0%|          | 0/98 [00:00<?, ?it/s]
# the image displays a bold, red, capitalized text ': 100%|██████████| 98/98 [01:39<00:00,  1.02s/it]
